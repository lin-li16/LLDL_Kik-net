# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torchvision
import torch.nn as nn
import warnings
import time
import os
import scipy.io
from tqdm import tqdm
from solver import train, test
from plot import plot_loss
from eventDataset import eqkDataset
warnings.filterwarnings("ignore")
sns.set_style('ticks')
# sns.set()
sns.set_context("poster")
plt.rcParams['font.sans-serif'] = 'Times New Roman'
torch.set_default_tensor_type(torch.DoubleTensor)

# %% [markdown]
# ## 导入数据

# %%
station = 'IBRH13'
dhacc = 981 * np.load(station + '_dhacc.npy')
upacc = 981 * np.load(station + '_upacc.npy')
# mdacc = 981 * np.load(station + '_mdacc.npy')
msg = np.load(station + '_msg.npy')

dt = 0.02
t = np.linspace(dt, dt * dhacc.shape[1], dhacc.shape[1])

# %%
# 用井下地震动的PGA进行数据标准化
PGA_dh = np.max(np.abs(dhacc), axis=1)
PGA_up = np.max(np.abs(upacc), axis=1)
for i in range(dhacc.shape[0]):
    dhacc[i, :] = dhacc[i, :] / PGA_dh[i]
    upacc[i, :] = upacc[i, :] / PGA_dh[i]

# %%
i = 23
t = np.linspace(0.02, 60, 3000)
plt.figure(figsize=((12, 3)))
plt.subplots_adjust(left=0,bottom=0,top=1,right=1,hspace=0.3,wspace=0.2)
plt.subplot(1, 2, 1)
plt.plot(t, dhacc[i, :], label='downhole', linewidth=1)
plt.xlabel('t (s)'), plt.ylabel('acc (gal)'), plt.legend(loc='upper right')
plt.subplot(1, 2, 2)
# plt.plot(t, mdacc[i, :], '--', label='simulate', linewidth=1)
plt.plot(t, upacc[i, :], label='record', linewidth=1)
plt.xlabel('t (s)'), plt.ylabel('acc (gal)'), plt.legend(loc='upper right')
# Out:
# (Text(0.5, 0, 't (s)'),
#  Text(0, 0.5, 'acc (gal)'),
#  <matplotlib.legend.Legend at 0x2373d817b88>)

# %% [markdown]
# ## 构造训练集、验证集和测试集

# %%
batch_size = 64
valid_size = 0.1
test_size = 0.1

numdata = dhacc.shape[0]
num_valid = int(valid_size * numdata)
num_test = int(test_size * numdata)
num_train = numdata - num_valid - num_test
index = list(range(numdata))
np.random.shuffle(index)
train_idx, valid_idx, test_idx = index[:num_train], index[num_train : num_train + num_valid], index[num_train + num_valid:]
# train_idx, valid_idx, test_idx = train_idx[0 : 500], valid_idx[0 : 15], test_idx[0 : 15]

data = scipy.io.loadmat(os.path.join(station + '_results', 'idx.mat'))
index = list(range(numdata))
train_idx = data['train_idx'].ravel().tolist()
test_idx = data['test_idx'].ravel().tolist()
valid_idx = list(set(index) - set(train_idx) - set(test_idx))

train_data, train_label = dhacc[train_idx, :, None], upacc[train_idx, :, None]
valid_data, valid_label = dhacc[valid_idx, :, None], upacc[valid_idx, :, None]
test_data, test_label = dhacc[test_idx, :, None], upacc[test_idx, :, None]

train_dataset = eqkDataset(train_data, train_label)
valid_dataset = eqkDataset(valid_data, valid_label)
test_dataset = eqkDataset(test_data, test_label)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size)
valid_loader = torch.utils.data.DataLoader(valid_dataset)
test_loader = torch.utils.data.DataLoader(test_dataset)

# %% [markdown]
# ## 绘制训练集和预测集数据的分布图

# %%
# data = scipy.io.loadmat(os.path.join(station + '_results', 'record_CNN', 'result.mat'))
# numdata = dhacc.shape[0]
# index = list(range(numdata))
# train_idx = data['train_idx'].ravel().tolist()
# test_idx = data['test_idx'].ravel().tolist()
# valid_idx = list(set(index) - set(train_idx) - set(test_idx))
with sns.axes_style('ticks'):
    sns.set_context("poster")
    plt.rcParams['font.sans-serif'] = 'Times New Roman'
    plt.figure(figsize=((24, 10)))
    plt.subplots_adjust(left=0.05,bottom=0.1,top=0.98,right=0.98,hspace=0.22,wspace=0.2)
    ax = plt.subplot(2, 4, 1)
    sns.histplot(msg[train_idx, 0], bins=20, binrange=[0, 200], color='#0072BD', label='Train')
    axins = ax.inset_axes((0.55, 0.45, 0.4, 0.3))
    sns.histplot(msg[train_idx, 0], bins=10, binrange=[200, 500], color='#0072BD', ax=axins)
    axins.set_ylabel('')
    plt.legend()
    ax = plt.subplot(2, 4, 5)
    sns.histplot(msg[test_idx, 0], bins=20, binrange=[0, 200], color='#D95319', label='Test')
    plt.xlabel('Depth (km)'), plt.legend()

    ax = plt.subplot(2, 4, 2)
    sns.histplot(msg[train_idx, 1], bins=20, binrange=[3, 8], color='#0072BD', label='Train')
    axins = ax.inset_axes((0.55, 0.65, 0.4, 0.3))
    sns.histplot(msg[train_idx, 1], bins=10, binrange=[7, 9], color='#0072BD', ax=axins)
    axins.set_ylabel('')
    plt.ylabel('')
    ax = plt.subplot(2, 4, 6)
    sns.histplot(msg[test_idx, 1], bins=20, binrange=[3, 8], color='#D95319', label='Test')
    plt.xlabel('Magnitude'), plt.ylabel('')

    ax = plt.subplot(2, 4, 3)
    sns.histplot(msg[train_idx, 2], bins=20, binrange=[0, 300], color='#0072BD', label='Train')
    axins = ax.inset_axes((0.55, 0.65, 0.4, 0.3))
    sns.histplot(msg[train_idx, 2], bins=10, binrange=[300, 1000], color='#0072BD', ax=axins)
    axins.set_ylabel('')
    plt.ylabel('')
    ax = plt.subplot(2, 4, 7)
    sns.histplot(msg[test_idx, 2], bins=20, binrange=[0, 300], color='#D95319', label='Test')
    plt.xlabel('Epicentral distance (km)'), plt.ylabel('')

    ax = plt.subplot(2, 4, 4)
    sns.histplot(msg[train_idx, 3], bins=20, binrange=[0, 200], color='#0072BD', label='Train')
    axins = ax.inset_axes((0.55, 0.65, 0.4, 0.3))
    sns.histplot(msg[train_idx, 3], bins=10, binrange=[200, 800], color='#0072BD', ax=axins)
    axins.set_ylabel('')
    plt.ylabel('')
    ax = plt.subplot(2, 4, 8)
    sns.histplot(msg[test_idx, 3], bins=20, binrange=[0, 200], color='#D95319', label='Test')
    plt.xlabel('PGA (gal)'), plt.ylabel('')
    plt.savefig(os.path.join(station + '_results', 'record_CNN', 'data.svg'))

# %% [markdown]
# ## 构建神经网络模型

# %%
class PhyRNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers):
        super(PhyRNN, self).__init__()
        n = 3000
        phi1 = np.concatenate([np.array([-3 / 2, 2, -1 / 2]), np.zeros([n - 3, ])])
        temp1 = np.concatenate([-1 / 2 * np.identity(n - 2), np.zeros([n - 2, 2])], axis=1)
        temp2 = np.concatenate([np.zeros([n - 2, 2]), 1 / 2 * np.identity(n - 2)], axis=1)
        phi2 = temp1 + temp2
        phi3 = np.concatenate([np.zeros([n - 3, ]), np.array([1 / 2, -2, 3 / 2])])
        Phi_t = 1 / dt * np.concatenate([np.reshape(phi1, [1, phi1.shape[0]]), phi2, np.reshape(phi3, [1, phi3.shape[0]])], axis=0)
        Phi_t = torch.tensor(Phi_t)
        if torch.cuda.is_available():
            Phi_t = Phi_t.cuda()
        self.Phi_t = Phi_t
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        super(PhyRNN, self).__init__()
        self.rnnlayer = nn.LSTM(input_size=self.input_size, hidden_size=self.hidden_size, num_layers=self.num_layers, batch_first=True)

        self.fc = nn.Sequential(
            nn.Linear(self.hidden_size, 16),
            nn.ReLU(inplace=True),
            # nn.Tanh(),
            nn.Linear(16, 4),
            nn.ReLU(inplace=True),
            # nn.Tanh(),
            nn.Linear(4, 1)
        )
        # self._initial_parameters()
        

    def forward(self, x):
        x, (ht, ct) = self.rnnlayer(x)
        x = self.fc(x)
        
        x_t = torch.matmul(self.Phi_t, x[:, :, 0].permute(1, 0))
        x_tt = torch.matmul(self.Phi_t, x_t)
        x_tt = x_tt.permute(1, 0)
        
        return x_tt[:, :, None]
    
    
    def _initial_parameters(self):
        for p in self.parameters():
            if p.dim() > 1:
                nn.init.constant_(p, 0.05)
            else:
                nn.init.constant_(p, 0)

# %%
def PhyCNNLoss(output, target):
    # PGA = torch.max(torch.abs(output_tt))/100
    # loss = torch.mean((output_tt/PGA - target/PGA).pow(2))
    # loss = torch.mean(((output - target)/torch.max(torch.abs(target))).pow(2))
    loss = torch.mean((output - target).pow(2))
    # loss = torch.mean((output_tt - target).pow(2)) + torch.mean(output.pow(2))
    return loss

# %%
max_epoch = 1000
disp_freq = -1
learning_rate = 0.001
# Net = PhyCNN(Phi_t)
Net = PhyRNN(1, 32, 3)
# GPU加速
if torch.cuda.is_available():
    Net = Net.cuda()
# optimizer = torch.optim.LBFGS(Net.parameters(), lr=learning_rate, max_iter=2)
optimizer = torch.optim.Adam(Net.parameters(), lr=learning_rate)
criterion = nn.MSELoss()
starttime = time.time()
train_best_model ,valid_best_model, last_model, train_loss, valid_loss = train(Net, PhyCNNLoss, optimizer, train_loader, valid_loader, max_epoch, disp_freq)
print('Training Time {:.4f}'.format(time.time()-starttime))
prediction = test(valid_best_model, PhyCNNLoss, test_loader)
torch.cuda.empty_cache()
# Out:
# Epoch [1/1000]	 Average training and validation loss: 7.7483E-01 7.8645E-01	Time: 17.08s
# Epoch [2/1000]	 Average training and validation loss: 7.5170E-01 7.6048E-01	Time: 15.90s
# Epoch [3/1000]	 Average training and validation loss: 7.1255E-01 7.3094E-01	Time: 15.91s
# Epoch [4/1000]	 Average training and validation loss: 6.9159E-01 7.2238E-01	Time: 15.89s
# Epoch [5/1000]	 Average training and validation loss: 6.8501E-01 7.1929E-01	Time: 15.95s
# Epoch [6/1000]	 Average training and validation loss: 6.8003E-01 7.1553E-01	Time: 16.01s
# Epoch [846/1000]	 Average training and validation loss: 4.7915E-01 4.9442E-01	Time: 16.95s
# Epoch [847/1000]	 Average training and validation loss: 4.7049E-01 4.9198E-01	Time: 16.87s
# Epoch [848/1000]	 Average training and validation loss: 4.6817E-01 4.9084E-01	Time: 16.86s
# Epoch [849/1000]	 Average training and validation loss: 4.6727E-01 4.9026E-01	Time: 16.85s
# Epoch [850/1000]	 Average training and validation loss: 4.6681E-01 4.8975E-01	Time: 16.86s
# Epoch [851/1000]	 Average training and validation loss: 4.6669E-01 4.8948E-01	Time: 16.84s
# Epoch [852/1000]	 Average training and validation loss: 4.6650E-01 4.8918E-01	Time: 16.84s
# Epoch [853/1000]	 Average training and validation loss: 4.6635E-01 4.8902E-01	Time: 16.88s
# Epoch [854/1000]	 Average training and validation loss: 4.6616E-01 4.8886E-01	Time: 16.85s
# Epoch [855/1000]	 Average training and validation loss: 4.6599E-01 4.8871E-01	Time: 16.85s
# Epoch [856/1000]	 Average training and validation loss: 4.6581E-01 4.8854E-01	Time: 16.88s
# Epoch [857/1000]	 Average training and validation loss: 4.6563E-01 4.8835E-01	Time: 16.91s
# Epoch [858/1000]	 Average training and validation loss: 4.6541E-01 4.8810E-01	Time: 16.95s
# Epoch [859/1000]	 Average training and validation loss: 4.6513E-01 4.8772E-01	Time: 16.97s
# Epoch [860/1000]	 Average training and validation loss: 4.6475E-01 4.8696E-01	Time: 16.99s
# Epoch [861/1000]	 Average training and validation loss: 4.6428E-01 4.8488E-01	Time: 16.99s
# Epoch [862/1000]	 Average training and validation loss: 4.6389E-01 4.8185E-01	Time: 17.02s
# Epoch [863/1000]	 Average training and validation loss: 4.6798E-01 4.8985E-01	Time: 16.99s
# Epoch [864/1000]	 Average training and validation loss: 4.6520E-01 4.8723E-01	Time: 16.97s
# Epoch [865/1000]	 Average training and validation loss: 4.6408E-01 4.8707E-01	Time: 17.07s
# Epoch [866/1000]	 Average training and validation loss: 4.6388E-01 4.8999E-01	Time: 16.98s
# Epoch [867/1000]	 Average training and validation loss: 4.6670E-01 4.8956E-01	Time: 16.95s
# Epoch [868/1000]	 Average training and validation loss: 4.6537E-01 4.8768E-01	Time: 16.95s
# Epoch [869/1000]	 Average training and validation loss: 4.6462E-01 4.8576E-01	Time: 17.06s
# Epoch [870/1000]	 Average training and validation loss: 4.6304E-01 4.8846E-01	Time: 16.95s
# Epoch [871/1000]	 Average training and validation loss: 4.9023E-01 5.2745E-01	Time: 16.98s
# Epoch [872/1000]	 Average training and validation loss: 4.9097E-01 5.1021E-01	Time: 16.96s
# Epoch [873/1000]	 Average training and validation loss: 4.8100E-01 5.0028E-01	Time: 16.95s
# Epoch [874/1000]	 Average training and validation loss: 4.7713E-01 4.9695E-01	Time: 16.95s
# Epoch [875/1000]	 Average training and validation loss: 4.7505E-01 4.9508E-01	Time: 16.97s
# Epoch [876/1000]	 Average training and validation loss: 4.7382E-01 4.9384E-01	Time: 16.99s
# Epoch [877/1000]	 Average training and validation loss: 4.7278E-01 4.9298E-01	Time: 16.95s
# Epoch [878/1000]	 Average training and validation loss: 4.7181E-01 4.9230E-01	Time: 16.97s
# Epoch [879/1000]	 Average training and validation loss: 4.7101E-01 4.9175E-01	Time: 16.94s
# Epoch [880/1000]	 Average training and validation loss: 4.7034E-01 4.9123E-01	Time: 16.96s
# Epoch [881/1000]	 Average training and validation loss: 4.6978E-01 4.9078E-01	Time: 16.96s
# Epoch [882/1000]	 Average training and validation loss: 4.6923E-01 4.9035E-01	Time: 16.95s
# Epoch [883/1000]	 Average training and validation loss: 4.6867E-01 4.8985E-01	Time: 16.96s
# Epoch [884/1000]	 Average training and validation loss: 4.6813E-01 4.8853E-01	Time: 16.93s
# Epoch [885/1000]	 Average training and validation loss: 4.6934E-01 4.9142E-01	Time: 16.96s
# Epoch [886/1000]	 Average training and validation loss: 4.7121E-01 4.9281E-01	Time: 16.96s
# Epoch [887/1000]	 Average training and validation loss: 4.6991E-01 4.9170E-01	Time: 16.96s
# Epoch [888/1000]	 Average training and validation loss: 4.6941E-01 4.9080E-01	Time: 16.99s
# Epoch [889/1000]	 Average training and validation loss: 4.6886E-01 4.9033E-01	Time: 16.98s
# Epoch [890/1000]	 Average training and validation loss: 4.6840E-01 4.9031E-01	Time: 16.95s
# Epoch [891/1000]	 Average training and validation loss: 4.6802E-01 4.9027E-01	Time: 17.00s
# Epoch [892/1000]	 Average training and validation loss: 4.6771E-01 4.9023E-01	Time: 16.96s
# Epoch [893/1000]	 Average training and validation loss: 4.6749E-01 4.9021E-01	Time: 16.94s
# Epoch [894/1000]	 Average training and validation loss: 4.6730E-01 4.9019E-01	Time: 16.96s
# Epoch [895/1000]	 Average training and validation loss: 4.6714E-01 4.9019E-01	Time: 16.97s
# Epoch [896/1000]	 Average training and validation loss: 4.6701E-01 4.9017E-01	Time: 16.95s
# Epoch [897/1000]	 Average training and validation loss: 4.6688E-01 4.9015E-01	Time: 16.96s
# Epoch [898/1000]	 Average training and validation loss: 4.6677E-01 4.9013E-01	Time: 16.97s
# Epoch [899/1000]	 Average training and validation loss: 4.6666E-01 4.9011E-01	Time: 16.98s
# Epoch [900/1000]	 Average training and validation loss: 4.6655E-01 4.9008E-01	Time: 16.96s
# Epoch [901/1000]	 Average training and validation loss: 4.6645E-01 4.9005E-01	Time: 16.95s
# Epoch [902/1000]	 Average training and validation loss: 4.6635E-01 4.9001E-01	Time: 16.93s
# Epoch [903/1000]	 Average training and validation loss: 4.6624E-01 4.8996E-01	Time: 16.92s
# Epoch [904/1000]	 Average training and validation loss: 4.6613E-01 4.8991E-01	Time: 16.99s
# Epoch [905/1000]	 Average training and validation loss: 4.6600E-01 4.8984E-01	Time: 16.99s
# Epoch [906/1000]	 Average training and validation loss: 4.6585E-01 4.8972E-01	Time: 16.98s
# Epoch [907/1000]	 Average training and validation loss: 4.6564E-01 4.8947E-01	Time: 16.99s
# Epoch [908/1000]	 Average training and validation loss: 4.6539E-01 4.8857E-01	Time: 16.96s
# Epoch [909/1000]	 Average training and validation loss: 4.7138E-01 4.9822E-01	Time: 16.97s
# Epoch [910/1000]	 Average training and validation loss: 4.7441E-01 4.9499E-01	Time: 16.90s
# Epoch [911/1000]	 Average training and validation loss: 4.7004E-01 4.9270E-01	Time: 16.80s
# Epoch [912/1000]	 Average training and validation loss: 4.6869E-01 4.9185E-01	Time: 16.78s
# Epoch [913/1000]	 Average training and validation loss: 4.6821E-01 4.9151E-01	Time: 16.75s
# Epoch [914/1000]	 Average training and validation loss: 4.6782E-01 4.9112E-01	Time: 16.77s
# Epoch [915/1000]	 Average training and validation loss: 4.6750E-01 4.9090E-01	Time: 16.77s
# Epoch [916/1000]	 Average training and validation loss: 4.6728E-01 4.9073E-01	Time: 16.79s
# Epoch [917/1000]	 Average training and validation loss: 4.6707E-01 4.9066E-01	Time: 16.81s
# Epoch [918/1000]	 Average training and validation loss: 4.6689E-01 4.9062E-01	Time: 16.80s
# Epoch [919/1000]	 Average training and validation loss: 4.6675E-01 4.9057E-01	Time: 16.84s
# Epoch [920/1000]	 Average training and validation loss: 4.6664E-01 4.9053E-01	Time: 16.78s
# Epoch [921/1000]	 Average training and validation loss: 4.6654E-01 4.9049E-01	Time: 16.83s
# Epoch [922/1000]	 Average training and validation loss: 4.6645E-01 4.9046E-01	Time: 16.83s
# Epoch [923/1000]	 Average training and validation loss: 4.6637E-01 4.9043E-01	Time: 16.89s
# Epoch [924/1000]	 Average training and validation loss: 4.6629E-01 4.9040E-01	Time: 16.89s
# Epoch [925/1000]	 Average training and validation loss: 4.6622E-01 4.9038E-01	Time: 16.92s
# Epoch [926/1000]	 Average training and validation loss: 4.6614E-01 4.9036E-01	Time: 16.97s
# Epoch [927/1000]	 Average training and validation loss: 4.6608E-01 4.9034E-01	Time: 16.92s
# Epoch [928/1000]	 Average training and validation loss: 4.6601E-01 4.9033E-01	Time: 16.96s
# Epoch [929/1000]	 Average training and validation loss: 4.6595E-01 4.9031E-01	Time: 16.94s
# Epoch [930/1000]	 Average training and validation loss: 4.6589E-01 4.9030E-01	Time: 16.94s
# Epoch [931/1000]	 Average training and validation loss: 4.6583E-01 4.9028E-01	Time: 16.95s
# Epoch [932/1000]	 Average training and validation loss: 4.6578E-01 4.9027E-01	Time: 16.96s
# Epoch [933/1000]	 Average training and validation loss: 4.6572E-01 4.9025E-01	Time: 16.93s
# Epoch [934/1000]	 Average training and validation loss: 4.6567E-01 4.9024E-01	Time: 16.96s
# Epoch [935/1000]	 Average training and validation loss: 4.6562E-01 4.9022E-01	Time: 16.95s
# Epoch [936/1000]	 Average training and validation loss: 4.6557E-01 4.9021E-01	Time: 16.90s
# Epoch [937/1000]	 Average training and validation loss: 4.6552E-01 4.9019E-01	Time: 16.96s
# Epoch [938/1000]	 Average training and validation loss: 4.6547E-01 4.9018E-01	Time: 16.95s
# Epoch [939/1000]	 Average training and validation loss: 4.6541E-01 4.9016E-01	Time: 16.94s
# Epoch [940/1000]	 Average training and validation loss: 4.6536E-01 4.9015E-01	Time: 16.92s
# Epoch [941/1000]	 Average training and validation loss: 4.6531E-01 4.9013E-01	Time: 16.96s
# Epoch [942/1000]	 Average training and validation loss: 4.6526E-01 4.9011E-01	Time: 16.99s
# Epoch [943/1000]	 Average training and validation loss: 4.6521E-01 4.9010E-01	Time: 16.96s
# Epoch [944/1000]	 Average training and validation loss: 4.6515E-01 4.9008E-01	Time: 16.98s
# Epoch [945/1000]	 Average training and validation loss: 4.6510E-01 4.9006E-01	Time: 16.95s
# Epoch [946/1000]	 Average training and validation loss: 4.6504E-01 4.9003E-01	Time: 16.97s
# Epoch [947/1000]	 Average training and validation loss: 4.6499E-01 4.9000E-01	Time: 16.95s
# Epoch [948/1000]	 Average training and validation loss: 4.6493E-01 4.8998E-01	Time: 16.94s
# Epoch [949/1000]	 Average training and validation loss: 4.6486E-01 4.8994E-01	Time: 16.96s
# Epoch [950/1000]	 Average training and validation loss: 4.6479E-01 4.8991E-01	Time: 16.95s
# Epoch [951/1000]	 Average training and validation loss: 4.6472E-01 4.8986E-01	Time: 16.97s
# Epoch [952/1000]	 Average training and validation loss: 4.6463E-01 4.8981E-01	Time: 16.97s
# Epoch [953/1000]	 Average training and validation loss: 4.6453E-01 4.8975E-01	Time: 16.95s
# Epoch [954/1000]	 Average training and validation loss: 4.6442E-01 4.8966E-01	Time: 16.94s
# Epoch [955/1000]	 Average training and validation loss: 4.6427E-01 4.8951E-01	Time: 16.94s
# Epoch [956/1000]	 Average training and validation loss: 4.6409E-01 4.8921E-01	Time: 16.95s
# Epoch [957/1000]	 Average training and validation loss: 4.6387E-01 4.8835E-01	Time: 16.95s
# Epoch [958/1000]	 Average training and validation loss: 4.6459E-01 4.9197E-01	Time: 16.95s
# Epoch [959/1000]	 Average training and validation loss: 4.6470E-01 4.8765E-01	Time: 16.96s
# Epoch [960/1000]	 Average training and validation loss: 4.6533E-01 4.9060E-01	Time: 16.97s
# Epoch [961/1000]	 Average training and validation loss: 4.6703E-01 4.9182E-01	Time: 16.96s
# Epoch [962/1000]	 Average training and validation loss: 4.6676E-01 4.9047E-01	Time: 16.96s
# Epoch [963/1000]	 Average training and validation loss: 4.6591E-01 4.8964E-01	Time: 16.96s
# Epoch [964/1000]	 Average training and validation loss: 4.6536E-01 4.8961E-01	Time: 16.93s
# Epoch [965/1000]	 Average training and validation loss: 4.6497E-01 4.8938E-01	Time: 16.98s
# Epoch [966/1000]	 Average training and validation loss: 4.6455E-01 4.8906E-01	Time: 16.97s
# Epoch [967/1000]	 Average training and validation loss: 4.6402E-01 4.8864E-01	Time: 16.97s
# Epoch [968/1000]	 Average training and validation loss: 4.6386E-01 4.8805E-01	Time: 16.96s
# Epoch [969/1000]	 Average training and validation loss: 4.6308E-01 4.9131E-01	Time: 16.96s
# Epoch [970/1000]	 Average training and validation loss: 4.6695E-01 4.9115E-01	Time: 16.94s
# Epoch [971/1000]	 Average training and validation loss: 4.6610E-01 4.9277E-01	Time: 16.94s
# Epoch [972/1000]	 Average training and validation loss: 4.6686E-01 4.9074E-01	Time: 16.93s
# Epoch [973/1000]	 Average training and validation loss: 4.6486E-01 4.8929E-01	Time: 16.96s
# Epoch [974/1000]	 Average training and validation loss: 4.6390E-01 4.8870E-01	Time: 16.93s
# Epoch [975/1000]	 Average training and validation loss: 4.6367E-01 4.8816E-01	Time: 16.95s
# Epoch [976/1000]	 Average training and validation loss: 4.6436E-01 4.8975E-01	Time: 16.97s
# Epoch [977/1000]	 Average training and validation loss: 4.6632E-01 4.9139E-01	Time: 16.94s
# Epoch [978/1000]	 Average training and validation loss: 4.6519E-01 4.8969E-01	Time: 16.95s
# Epoch [979/1000]	 Average training and validation loss: 4.6499E-01 4.8961E-01	Time: 16.97s
# Epoch [980/1000]	 Average training and validation loss: 4.6461E-01 4.8939E-01	Time: 16.91s
# Epoch [981/1000]	 Average training and validation loss: 4.6441E-01 4.8937E-01	Time: 16.89s
# Epoch [982/1000]	 Average training and validation loss: 4.6415E-01 4.8926E-01	Time: 16.87s
# Epoch [983/1000]	 Average training and validation loss: 4.6383E-01 4.8899E-01	Time: 17.02s
# Epoch [984/1000]	 Average training and validation loss: 4.6343E-01 4.8853E-01	Time: 16.89s
# Epoch [985/1000]	 Average training and validation loss: 4.6303E-01 4.8768E-01	Time: 16.90s
# Epoch [986/1000]	 Average training and validation loss: 4.7308E-01 5.1077E-01	Time: 16.90s
# Epoch [987/1000]	 Average training and validation loss: 4.8403E-01 5.0404E-01	Time: 16.89s
# Epoch [988/1000]	 Average training and validation loss: 4.7396E-01 4.9686E-01	Time: 16.84s
# Epoch [989/1000]	 Average training and validation loss: 4.7033E-01 4.9255E-01	Time: 16.72s
# Epoch [990/1000]	 Average training and validation loss: 4.6871E-01 4.9158E-01	Time: 16.69s
# Epoch [991/1000]	 Average training and validation loss: 4.6770E-01 4.9090E-01	Time: 16.66s
# Epoch [992/1000]	 Average training and validation loss: 4.6699E-01 4.9044E-01	Time: 16.68s
# Epoch [993/1000]	 Average training and validation loss: 4.6652E-01 4.9026E-01	Time: 16.67s
# Epoch [994/1000]	 Average training and validation loss: 4.6617E-01 4.9015E-01	Time: 16.68s
# Epoch [995/1000]	 Average training and validation loss: 4.6591E-01 4.9004E-01	Time: 16.66s
# Epoch [996/1000]	 Average training and validation loss: 4.6570E-01 4.8998E-01	Time: 16.68s
# Epoch [997/1000]	 Average training and validation loss: 4.6552E-01 4.8992E-01	Time: 16.70s
# Epoch [998/1000]	 Average training and validation loss: 4.6536E-01 4.8986E-01	Time: 16.68s
# Epoch [999/1000]	 Average training and validation loss: 4.6522E-01 4.8982E-01	Time: 16.70s
# Epoch [1000/1000]	 Average training and validation loss: 4.6514E-01 4.8977E-01	Time: 16.71s
# Training Time 17005.1982
# Testing...
# Test Loss 0.4680

# %%
plot_loss(train_loss, valid_loss)
torch.save(train_best_model, os.path.join(station + '_results', 'record_LSTM', 'trainbest.pt'))
torch.save(valid_best_model, os.path.join(station + '_results', 'record_LSTM', 'validbest.pt'))
torch.save(last_model, os.path.join(station + '_results', 'record_LSTM', 'last.pt'))

# %%
train_pred = np.zeros(train_label.shape)
pbar = tqdm(range(train_data.shape[0]), desc='计算中', ncols=100)
for i in pbar:
    y = valid_best_model(torch.tensor(train_data[i:i+1, :, :]).cuda())
    train_pred[i, :, :] = y.cpu().detach().numpy()
    train_data[i, :, 0] = train_data[i, :, 0] * PGA_dh[train_idx[i]]
    train_label[i, :, 0] = train_label[i, :, 0] * PGA_dh[train_idx[i]]
    train_pred[i, :, 0] = train_pred[i, :, 0] * PGA_dh[train_idx[i]]
# Out:
# 计算中: 100%|█████████████████████████████████████████████████████| 802/802 [01:08<00:00, 11.64it/s]

# %%
dof = 0
# for i in range(0, train_pred.shape[0]):
for i in range(0, train_pred.shape[0], int(train_pred.shape[0] / 10)):
    plt.figure(figsize=((12, 3)))
    plt.subplots_adjust(left=0,bottom=0,top=1,right=1,hspace=0.3,wspace=0.2)
    plt.subplot(1, 2, 1)
    plt.plot(t, train_data[i, :, dof], label='downhole', linewidth=1)
    plt.xlabel('t (s)'), plt.ylabel('acc (gal)'), plt.legend(loc='upper right')
    plt.subplot(1, 2, 2)
    plt.plot(t, train_label[i, :, dof], label='record', linewidth=1)
    plt.plot(t, train_pred[i, :, dof], '--', label='prediction', linewidth=1)
    plt.xlabel('t (s)'), plt.ylabel('acc (gal)'), plt.legend(loc='upper right')
    # plt.savefig(os.path.join(station + '_results', 'record_LSTM', 'figures', 'train{:d}.svg'.format(i)))
    # plt.close()

# %%
test_pred = valid_best_model(torch.tensor(test_data).cuda())
test_pred = test_pred.cpu().detach().numpy()
for i in range(test_data.shape[0]):
    test_data[i, :, 0] = test_data[i, :, 0] * PGA_dh[test_idx[i]]
    test_label[i, :, 0] = test_label[i, :, 0] * PGA_dh[test_idx[i]]
    test_pred[i, :, 0] = test_pred[i, :, 0] * PGA_dh[test_idx[i]]
torch.cuda.empty_cache()

# %%
dof = 0
for i in range(0, test_pred.shape[0], int(test_pred.shape[0]/10)):
# for i in range(0, test_pred.shape[0]):
    plt.figure(figsize=((12, 3)))
    plt.subplots_adjust(left=0,bottom=0,top=1,right=1,hspace=0.3,wspace=0.2)
    plt.subplot(1, 2, 1)
    plt.plot(t, test_data[i, :, dof], label='downhole', linewidth=1)
    plt.xlabel('t (s)'), plt.ylabel('acc (gal)'), plt.legend(loc='upper right')
    plt.subplot(1, 2, 2)
    plt.plot(t, test_label[i, :, dof], label='record', linewidth=1)
    plt.plot(t, test_pred[i, :, dof], '--', label='prediction', linewidth=1)
    plt.xlabel('t (s)'), plt.ylabel('acc (gal)'), plt.legend(loc='upper right')
    # plt.savefig(os.path.join(station + '_results', 'record_LSTM', 'figures', 'test{:d}.svg'.format(i)))
    # plt.close()

# %%
scipy.io.savemat(os.path.join(station + '_results', 'record_LSTM', 'result.mat'),
                 {'train_data': train_data, 'train_idx': train_idx, 'valid_idx': valid_idx, 'test_idx': test_idx, 'train_label': train_label, 'train_pred': train_pred, 'test_data': test_data,
                  'test_label': test_label, 'test_pred': test_pred, 'train_loss': train_loss, 'valid_loss': valid_loss, 'time': t, 'dt': dt})
